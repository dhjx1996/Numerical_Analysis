# %% [markdown]
# # Bisection Method and Newton's method
#
# ## by Dion Ho
#
# ### Last updated: January 20, 2019
#
#
# # Import Python Libraries

# %%
import numpy as np

# %% [markdown]
# # Defining the Bisection Routine

# %%
def bisection_method(a,b,f,tol,N):
    FA,FB = f(a), f(b)
    iteration = 1
    if FA*FB<0:
        print ("iter      a           b            root:(x,_)           root:(_,y)")
        print ("------------------------------------------------------------------")
        p = (a + b)/2
        FP = f(p)
        while (np.abs((b-a)/2)>tol) & (iteration <= N):
            if FA*FP<0:
                b=p
                FB=FP
            else:
                a=p
                FA=FP
            p = (a+b)/2
            FP = f(p)
            print('{:>3d}  {:> 10.5f}  {:> 10.5f}  {:> 22.16f}  {:>13.6e}'.format(iteration, a, b, p, abs(FP)))
            iteration = iteration + 1
        if np.abs((b-a)/2)>tol:
            print("Method failed to converge")
        else:
            return p
    else:
             print("Cannot ensure existence of root")

# %% [markdown]
# # Testing the Bisection Method
# Here, let's try to solve the equation $3x^2 + 10x + 8 = 0$ on the interval $\left[-1.5,0\right]$.

# %%
f = lambda x: 3*x**2 + 10*x + 8

# %%
bisection_method(-1.5,0,f,1e-9,50)
# Out:
# iter      a           b            root:(x,_)           root:(_,y)
# ------------------------------------------------------------------
#   1    -1.50000    -0.75000     -1.1250000000000000   5.468750e-01
#   2    -1.50000    -1.12500     -1.3125000000000000   4.296875e-02
#   3    -1.50000    -1.31250     -1.4062500000000000   1.298828e-01
#   4    -1.40625    -1.31250     -1.3593750000000000   5.004883e-02
#   5    -1.35938    -1.31250     -1.3359375000000000   5.187988e-03
#   6    -1.33594    -1.31250     -1.3242187500000000   1.847839e-02
#   7    -1.33594    -1.32422     -1.3300781250000000   6.542206e-03
#   8    -1.33594    -1.33008     -1.3330078125000000   6.513596e-04
#   9    -1.33594    -1.33301     -1.3344726562500000   2.274752e-03
#  10    -1.33447    -1.33301     -1.3337402343750000   8.133054e-04
#  11    -1.33374    -1.33301     -1.3333740234375000   8.137524e-05
#  12    -1.33337    -1.33301     -1.3331909179687500   2.848916e-04
#  13    -1.33337    -1.33319     -1.3332824707031250   1.017330e-04
#  14    -1.33337    -1.33328     -1.3333282470703125   1.017260e-05
#  15    -1.33337    -1.33333     -1.3333511352539062   3.560289e-05
#  16    -1.33335    -1.33333     -1.3333396911621094   1.271554e-05
#  17    -1.33334    -1.33333     -1.3333339691162109   1.271565e-06
#  18    -1.33333    -1.33333     -1.3333311080932617   4.450495e-06
#  19    -1.33333    -1.33333     -1.3333325386047363   1.589459e-06
#  20    -1.33333    -1.33333     -1.3333332538604736   1.589457e-07
#  21    -1.33333    -1.33333     -1.3333336114883423   5.563098e-07
#  22    -1.33333    -1.33333     -1.3333334326744080   1.986821e-07
#  23    -1.33333    -1.33333     -1.3333333432674408   1.986821e-08
#  24    -1.33333    -1.33333     -1.3333332985639572   6.953876e-08
#  25    -1.33333    -1.33333     -1.3333333209156990   2.483527e-08
#  26    -1.33333    -1.33333     -1.3333333320915699   2.483527e-09
#  27    -1.33333    -1.33333     -1.3333333376795053   8.692343e-09
#  28    -1.33333    -1.33333     -1.3333333348855376   3.104407e-09
#  29    -1.33333    -1.33333     -1.3333333334885538   3.104397e-10
#  30    -1.33333    -1.33333     -1.3333333327900618   1.086543e-09
# -1.3333333327900618

# %% [markdown]
# # Newton's Method

# %%
def newton_method(x0,f,fp,tol,N):
    F = f(x0)
    Fp = fp(x0)
    iteration = 1
    print ("iter      grad         root:(x,_)           root:(_,y)")
    print ("------------------------------------------------------")
    while (iteration<=N) & (np.abs(F)>tol):
        x = (Fp*x0 - F)/Fp
        x0 = x
        F = f(x0)
        Fp = fp(x0)
        print('{:>3d}  {:> 10.5f}  {:> 22.16f}  {:>13.6e}'.format(iteration, Fp, x, abs(F)))
        iteration = iteration + 1
    if np.abs(F)<=tol:
        return x0
    else:
        print("Method failed to converge. Try harder!")

# %%
f = lambda x: 3*x**2 + 10*x + 8
fp = lambda x: 6*x + 10
newton_method(99,f,fp,1e-15,20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-87f687fd5bdb> in <module>
#       1 f = lambda x: 3*x**2 + 10*x + 8
#       2 fp = lambda x: 6*x + 10
# ----> 3 newton_method(99,f,fp,1e-15,20)
#
# NameError: name 'newton_method' is not defined

# %%
f = lambda x: x**3 - 1
fp = lambda x: 3*(x**2)
newton_method(1.5,f,fp,1e-10,20) #Newton's method converges quadratically fast.
bisection_method(0,1.5,f,1e-10,50)
# Out:
# iter      grad         root:(x,_)           root:(_,y)
# ------------------------------------------------------
#   1     3.95473      1.1481481481481481   5.135396e-01
#   2     3.11077      1.0182937012628306   5.589120e-02
#   3     3.00196      1.0003266792741528   9.803580e-04
#   4     3.00000      1.0000001066728832   3.200187e-07
#   5     3.00000      1.0000000000000113   3.397282e-14
# iter      a           b            root:(x,_)           root:(_,y)
# ------------------------------------------------------------------
#   1     0.75000     1.50000      1.1250000000000000   4.238281e-01
#   2     0.75000     1.12500      0.9375000000000000   1.760254e-01
#   3     0.93750     1.12500      1.0312500000000000   9.671021e-02
#   4     0.93750     1.03125      0.9843750000000000   4.614639e-02
#   5     0.98438     1.03125      1.0078125000000000   2.362108e-02
#   6     0.98438     1.00781      0.9960937500000000   1.167303e-02
#   7     0.99609     1.00781      1.0019531250000000   5.870827e-03
#   8     0.99609     1.00195      0.9990234375000000   2.926827e-03
#   9     0.99902     1.00195      1.0004882812500000   1.465559e-03
#  10     0.99902     1.00049      0.9997558593750000   7.322431e-04
#  11     0.99976     1.00049      1.0001220703125000   3.662556e-04
#  12     0.99976     1.00012      0.9999389648437500   1.830943e-04
#  13     0.99994     1.00012      1.0000305175781250   9.155553e-05
#  14     0.99994     1.00003      0.9999847412109375   4.577567e-05
#  15     0.99998     1.00003      1.0000076293945312   2.288836e-05
#  16     0.99998     1.00001      0.9999961853027344   1.144405e-05
#  17     1.00000     1.00001      1.0000019073486328   5.722057e-06
#  18     1.00000     1.00000      0.9999990463256836   2.861020e-06
#  19     1.00000     1.00000      1.0000004768371582   1.430512e-06
#  20     1.00000     1.00000      0.9999997615814209   7.152556e-07
#  21     1.00000     1.00000      1.0000001192092896   3.576279e-07
#  22     1.00000     1.00000      0.9999999403953552   1.788139e-07
#  23     1.00000     1.00000      1.0000000298023224   8.940697e-08
#  24     1.00000     1.00000      0.9999999850988388   4.470348e-08
#  25     1.00000     1.00000      1.0000000074505806   2.235174e-08
#  26     1.00000     1.00000      0.9999999962747097   1.117587e-08
#  27     1.00000     1.00000      1.0000000018626451   5.587935e-09
#  28     1.00000     1.00000      0.9999999990686774   2.793968e-09
#  29     1.00000     1.00000      1.0000000004656613   1.396984e-09
#  30     1.00000     1.00000      0.9999999997671694   6.984919e-10
#  31     1.00000     1.00000      1.0000000001164153   3.492460e-10
#  32     1.00000     1.00000      0.9999999999417923   1.746230e-10
#  33     1.00000     1.00000      1.0000000000291038   8.731149e-11
# 1.0000000000291038
